# %%
import pandas as pd

# %%
df=pd.read_csv("CustomerProfileData1 (1).csv")
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df.dtypes
# Out:
# Column1           object
# Type              object
# Status            object
# City              object
# State             object
# PostalCode       float64
# GenderCode        object
# BirthDate         object
# MaritalStatus     object
# Enrolled on       object
# Living status     object
# Age                int64
# Age Group         object
# Month_Year        object
# Weak Num          object
# dtype: object

# %%
df.columns
# Out:
# Index(['Column1', 'Type', 'Status', 'City', 'State', 'PostalCode',
#        'GenderCode', 'BirthDate', 'MaritalStatus', 'Enrolled on ',
#        'Living status', 'Age', 'Age Group', 'Month_Year', 'Weak Num'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.describe()
# Out:
#          PostalCode           Age
# count    9999.00000  10000.000000
# mean   473059.69507     38.703600
# std     84797.46280     17.016048
# min      8905.00000      2.000000
# 25%    411030.00000     29.000000
# 50%    500034.00000     35.000000
# 75%    500082.00000     43.000000
# max    854337.00000    121.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Column1        10000 non-null  object
#  1   Type           10000 non-null  object
#  2   Status         10000 non-null  object
#  3   City           9927 non-null   object
#  4   State          9874 non-null   object
#  5   PostalCode     9999 non-null   float64
#  6   GenderCode     10000 non-null  object
#  7   BirthDate      10000 non-null  object
#  8   MaritalStatus  10000 non-null  object
#  9   Enrolled on    10000 non-null  object
#  10  Living status  10000 non-null  object
#  11  Age            10000 non-null  int64
#  12  Age Group      10000 non-null  object
#  13  Month_Year     10000 non-null  object
#  14  Weak Num       10000 non-null  object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 1.1+ MB

# %%
df.mean()
# Out:
# PostalCode    473059.69507
# Age               38.70360
# dtype: float64

# %%
df.groupby(["GenderCode"]).mean()
# Out:
#                 PostalCode         Age
# GenderCode
# FEMALE       464645.714482   37.136567
# MALE         476853.695614   37.192246
# Not Mention  462348.402116  117.888889
# OTHER        494141.352941   38.588235

# %%
df["MaritalStatus"].sum()
# Out:
# '...'

# %%
pd.crosstab(df.GenderCode , df.MaritalStatus)
# Out:
# MaritalStatus     M    U
# GenderCode
# FEMALE         2836   71
# MALE           6635  252
# Not Mention     189    0
# OTHER            16    1

# %%
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df["PostalCode"].plot()
# Out:
# <AxesSubplot:>

# %%
df["Age"].hist()
# Out:
# <AxesSubplot:>

# %%
df["Type"]=df["Type"].str.lower()
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df_missing=pd.read_csv("CustomerProfileData1 (1) - missing.csv")
df_missing
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active        NaN
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active        NaN
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df_missing["Age"].fillna(df_missing["Age"].mean(),inplace=True)
df_missing
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  Individual  Active        NaN
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  Individual  Active        NaN
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df_missing.dropna(inplace=True)
df_missing
# Out:
#                                    Column1        Type  Status       City  \
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  Individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  Individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  Individual  Active  Hyderabad
# 5     0040234A-F78A-11e8-BDC8-005056991469  Individual  Active  Hyderabad
# 6     00444C44-A9F4-11e8-9E9E-0050569D5A2F  Individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9993  0461474C-E79F-11e9-87B4-005056981C55  Individual  Active     Mumbai
# 9994  04614753-E79F-11e9-87B4-005056981C55  Individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  Individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  Individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  Individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df_missing.to_csv("CustomerProfileData1 (1)-dropped.csv")

# %%
seats_column=pd.Series([5,5,5,5,5,5,5])
df["seats"]=seats_column
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df["seats"].fillna (5,inplace=True)
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df["division"]=df["Age"]/df["seats"]
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df["Number of seats"]=4
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df.drop("division",axis=1,inplace=True)

# %%
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df_shuffled=df.sample(frac=1)
df_shuffled
# Out:
#                                    Column1        Type  Status  \
# 9089  046142B5-E79F-11e9-87B4-005056981C55  individual  Active
# 2504  01DAB49F-E5AE-11e8-92BA-0050569973AB  individual  Active
# 7862  00F0AC36-CFFC-11e8-9F6C-0050569D7549    business  Active
# 7024  01E92C6A-89A8-11e9-8ED4-005056991469  individual  Active
# 3108  03D152BF-DBBA-11e9-A982-0050569857FB  individual  Active
# ...                                    ...         ...     ...
# 5657  007B0CAA-61A2-11e8-814C-0050569D7549  individual  Active
# 7848  00CCDD53-7BAF-11e9-A1D2-005056991469    business  Active
# 83    0385B3AB-B9F1-11e8-9A48-00505682069A  individual  Active
# 8597  00CE8C9E-310E-11ea-BEE4-0050569857FB  individual  Active
# 4132  0175E121-A12A-11e8-B0C2-0050569D7549  individual  Active
#
#                 City           State  PostalCode   GenderCode   BirthDate  \
# 9089          Mumbai     MAHARASHTRA    400053.0       FEMALE   9/22/1980
# ...

# %%
df_shuffled.sample(frac=0.2)
# Out:
#                                    Column1        Type  Status  \
# 4200  03714309-CD1D-11e8-A128-0050569D7549  individual  Active
# 2076  02DA9A1D-5F21-11e9-AA6A-005056991469  individual  Active
# 6456  038B776E-6F78-11e8-BF92-0050568252F9  individual  Active
# 8545  0082586C-282A-11ea-9C7E-0050569953B7  individual  Active
# 6112  038EF8AF-BC1F-11e9-8CE8-0050569857FB  individual  Active
# ...                                    ...         ...     ...
# 4014  00A48CC8-198C-11e9-BF7E-005056984FDD  individual  Active
# 1652  043432AD-9F96-11e8-A89C-0050568252F9  individual  Active
# 5421  0345DF42-5FCB-11e8-8E4A-0050568260A3  individual  Active
# 174   02B9B8DE-8CB7-11e9-8CD8-005056991469  individual  Active
# 1874  01487B2F-97A7-11e8-A57A-0050569D5A2F  individual  Active
#
#                 City           State  PostalCode GenderCode  BirthDate  \
# 4200      Karimnagar       TELANGANA    505001.0       MALE  6/23/1982
# ...

# %%
df_shuffled.reset_index(inplace=True)
df_shuffled
# Out:
#       index                               Column1        Type  Status  \
# 0      9089  046142B5-E79F-11e9-87B4-005056981C55  individual  Active
# 1      2504  01DAB49F-E5AE-11e8-92BA-0050569973AB  individual  Active
# 2      7862  00F0AC36-CFFC-11e8-9F6C-0050569D7549    business  Active
# 3      7024  01E92C6A-89A8-11e9-8ED4-005056991469  individual  Active
# 4      3108  03D152BF-DBBA-11e9-A982-0050569857FB  individual  Active
# ...     ...                                   ...         ...     ...
# 9995   5657  007B0CAA-61A2-11e8-814C-0050569D7549  individual  Active
# 9996   7848  00CCDD53-7BAF-11e9-A1D2-005056991469    business  Active
# 9997     83  0385B3AB-B9F1-11e8-9A48-00505682069A  individual  Active
# 9998   8597  00CE8C9E-310E-11ea-BEE4-0050569857FB  individual  Active
# 9999   4132  0175E121-A12A-11e8-B0C2-0050569D7549  individual  Active
#
#                 City           State  PostalCode   GenderCode   BirthDate  \
# ...

# %%
df['seats']=df['seats'].apply(lambda x:x/1.6)
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df.loc[3]
# Out:
# Column1            000D7905-FA2B-11e8-9742-005056984FDD
# Type                                         individual
# Status                                           Active
# City                                          Hyderabad
# State                                         TELANGANA
# PostalCode                                       500084
# GenderCode                                         MALE
# BirthDate                                     9/19/1990
# MaritalStatus                                         M
# Enrolled on                                   12/7/2018
# Living status                      couple with children
# Age                                                  30
# Age Group                                   30-35 Years
# Month_Year                                       18-Dec
# Weak Num                                       Weak: 49
# seats                                             3.125
# Number of seats                                       4
# ...

# %%
df.loc[[3]]
# Out:
#                                 Column1        Type  Status       City  \
# 3  000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
#
#        State  PostalCode GenderCode  BirthDate MaritalStatus Enrolled on   \
# 3  TELANGANA    500084.0       MALE  9/19/1990             M    12/7/2018
#
#           Living status  Age    Age Group Month_Year  Weak Num  seats  \
# 3  couple with children   30  30-35 Years     18-Dec  Weak: 49  3.125
#
#    Number of seats
# 3                4

# %%
df.loc[[8,9]]
# Out:
#                                 Column1        Type  Status       City  \
# 8  005A6507-FE81-11e8-BE60-0050569973AB  individual  Active  Hyderabad
# 9  0092CCEE-A17F-11e9-9C14-005056991469  individual  Active  Hyderabad
#
#        State  PostalCode GenderCode  BirthDate MaritalStatus Enrolled on   \
# 8  TELANGANA    500084.0       MALE  10/1/1959             M   12/13/2018
# 9  TELANGANA    500084.0       MALE  1/26/1982             M     7/8/2019
#
#              Living status  Age    Age Group Month_Year  Weak Num  seats  \
# 8  Couple without children   61    60+ Years     18-Dec  Weak: 50  3.125
# 9     couple with children   39  35-40 Years     19-Jul  Weak: 28  3.125
#
#    Number of seats
# 8                4
# 9                4

# %%
df.loc[5:8]
# Out:
#                                 Column1        Type  Status       City  \
# 5  0040234A-F78A-11e8-BDC8-005056991469  individual  Active  Hyderabad
# 6  00444C44-A9F4-11e8-9E9E-0050569D5A2F  individual  Active  Hyderabad
# 7  00548C6A-029A-11e9-80A8-005056991469  individual  Active  Hyderabad
# 8  005A6507-FE81-11e8-BE60-0050569973AB  individual  Active  Hyderabad
#
#        State  PostalCode GenderCode  BirthDate MaritalStatus Enrolled on   \
# 5  TELANGANA    500084.0       MALE  6/12/1986             M    12/4/2018
# 6  TELANGANA    500084.0       MALE   6/5/1978             M    8/27/2018
# 7  TELANGANA    500084.0       MALE  1/18/1994             M   12/18/2018
# 8  TELANGANA    500084.0       MALE  10/1/1959             M   12/13/2018
#
#              Living status  Age    Age Group Month_Year  Weak Num  seats  \
# 5     couple with children   34  30-35 Years     18-Dec  Weak: 49  3.125
# 6     couple with children   42  40- 45Years     18-Aug  Weak: 35  3.125
# ...

# %%
df.loc[4,'GenderCode']='FEMALE'
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df.loc[5:8:2]
# Out:
#                                 Column1        Type  Status       City  \
# 5  0040234A-F78A-11e8-BDC8-005056991469  individual  Active  Hyderabad
# 7  00548C6A-029A-11e9-80A8-005056991469  individual  Active  Hyderabad
#
#        State  PostalCode GenderCode  BirthDate MaritalStatus Enrolled on   \
# 5  TELANGANA    500084.0       MALE  6/12/1986             M    12/4/2018
# 7  TELANGANA    500084.0       MALE  1/18/1994             M   12/18/2018
#
#              Living status  Age    Age Group Month_Year  Weak Num  seats  \
# 5     couple with children   34  30-35 Years     18-Dec  Weak: 49  3.125
# 7  Couple without children   27  25-30 Years     18-Dec  Weak: 51  3.125
#
#    Number of seats
# 5                4
# 7                4

# %%
df.loc[8:5:-2]
# Out:
#                                 Column1        Type  Status       City  \
# 8  005A6507-FE81-11e8-BE60-0050569973AB  individual  Active  Hyderabad
# 6  00444C44-A9F4-11e8-9E9E-0050569D5A2F  individual  Active  Hyderabad
#
#        State  PostalCode GenderCode  BirthDate MaritalStatus Enrolled on   \
# 8  TELANGANA    500084.0       MALE  10/1/1959             M   12/13/2018
# 6  TELANGANA    500084.0       MALE   6/5/1978             M    8/27/2018
#
#              Living status  Age    Age Group Month_Year  Weak Num  seats  \
# 8  Couple without children   61    60+ Years     18-Dec  Weak: 50  3.125
# 6     couple with children   42  40- 45Years     18-Aug  Weak: 35  3.125
#
#    Number of seats
# 8                4
# 6                4

# %%
df['Age']>40
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Age, Length: 10000, dtype: bool

# %%
df[df['Age']>40]
# Out:
#                                    Column1        Type  Status       City  \
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# 6     00444C44-A9F4-11e8-9E9E-0050569D5A2F  individual  Active  Hyderabad
# 8     005A6507-FE81-11e8-BE60-0050569973AB  individual  Active  Hyderabad
# 16    00F58D47-FB44-11e8-811C-0050569973AB  individual  Active  Hyderabad
# 17    01130CBF-E692-11e9-956A-005056984FDD  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9983  043D87C0-FAEB-11e9-A0E2-005056981C55  individual  Active     Mumbai
# 9989  043F4B4F-4F59-11e8-A4FE-0050569D7549  individual  Active     Mumbai
# 9990  043F4C96-4F59-11e8-A4FE-0050569D7549  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
#
#             State  PostalCode GenderCode  BirthDate MaritalStatus  \
# ...

# %%
df=df.rename(columns={'seats':'seat_column'})
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                    Column1        Type  Status       City  \
# 0     0001F736-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 1     0001F87E-9FE7-11e8-9E9C-00505682069A  individual  Active  Hyderabad
# 2     000D76D7-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 3     000D7905-FA2B-11e8-9742-005056984FDD  individual  Active  Hyderabad
# 4     002D134F-A76C-11e8-8B0C-0050568252F9  individual  Active  Hyderabad
# ...                                    ...         ...     ...        ...
# 9995  0466271E-1E6A-11e8-8044-00505682069A  individual  Active     Mumbai
# 9996  0467D037-D12F-11e8-8DAE-0050568260A3  individual  Active     Mumbai
# 9997  0473AD82-C8B0-11e9-8A4E-005056991469  individual  Active     Mumbai
# 9998  04751E6A-7785-11e8-B148-00505682069A  individual  Active     Mumbai
# 9999  0475FEB5-0263-11ea-9522-005056981C55  individual  Active     Mumbai
#
#             State  PostalCode GenderCode   BirthDate MaritalStatus  \
# ...
